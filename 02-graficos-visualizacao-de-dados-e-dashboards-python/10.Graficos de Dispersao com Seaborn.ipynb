# %% [markdown]
# <font size="5">Gráficos e Dashboards</font>

# %% [markdown]
# <font size="4">Gráficos de Dispersão com Seaborn</font>

# %%
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

# %%
#Importando dados

base = pd.read_csv("../data/co2.csv")

# %%
#Visualizando dados

base.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
#Gráfico de dispersão utilizando os atributos conc e uptake, agrupamento pelo type

srn.scatterplot(data=base, x='conc', y='uptake', hue='Type')
# Out:
# <Axes: xlabel='conc', ylabel='uptake'>

# %%
#Seleção de registros específicos da base de dados (Quebec e Mississipi)

q = base.loc[base['Type'] == 'Quebec']
m = base.loc[base['Type'] == 'Mississippi']

# %%
#Sub-gráfico mostrando graficos sobre cada região

plt.figure(figsize=(10, 5))  # Ajuste o tamanho se necessário
plt.subplot(1, 2, 1)
srn.scatterplot(x=q.conc, y=q.uptake)
plt.title('Quebec')
plt.subplot(1, 2, 2)
srn.scatterplot(x=m.conc, y=m.uptake)
plt.title('Mississippi')
plt.tight_layout()
plt.show()

# %%
#Seleção de registros específicos da base de dados (chilled e nonchilled)

ch = base.loc[base["Treatment"] == "chilled"]
nc = base.loc[base["Treatment"] == "nonchilled"]

# %%
#Sub-gráfico mostrando graficos de dispersão de chilled e nonchilled

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
srn.scatterplot(x=ch.conc, y=ch.uptake)
plt.title('Chilled')
plt.subplot(1, 2, 2)
srn.scatterplot(x=nc.conc, y=nc.uptake)
plt.title('Non chilled')
plt.tight_layout()
plt.show()

# %%
#Importando dados

base2 = pd.read_csv("../data/esoph.csv")

# %%
#Visualizando dados

base2
# Out:
#     agegp      alcgp     tobgp  ncases  ncontrols
# 0   25-34  0-39g/day  0-9g/day       0         40
# 1   25-34  0-39g/day     10-19       0         10
# 2   25-34  0-39g/day     20-29       0          6
# 3   25-34  0-39g/day       30+       0          5
# 4   25-34      40-79  0-9g/day       0         27
# ..    ...        ...       ...     ...        ...
# 83    75+      40-79       30+       1          1
# 84    75+     80-119  0-9g/day       1          1
# 85    75+     80-119     10-19       1          1
# 86    75+       120+  0-9g/day       2          2
# 87    75+       120+     10-19       1          1
#
# [88 rows x 5 columns]

# %%
#Gráfico entre atributos alcgp e ncontrols

srn.catplot(x = "alcgp", y = "ncontrols", data = base2, jitter = False)

# %%
#Gráfico entre os atributos alcgp e nctcontrols com agrupamento por tobgp

srn.catplot(x = "alcgp", y = "ncontrols", data = base2, col = "tobgp")
