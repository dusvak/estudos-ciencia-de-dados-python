# %% [markdown]
# <font size="5">Gráficos e Dashboards</font>

# %% [markdown]
# <font size="4">Boxplots</font>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importando dados

base = pd.read_csv("../data/trees.csv")

# %%
#Visualizando dados

base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
#Visualizando dados em Boxplot

#patch_artist diz se o gráfico será preenchido
#showfliers diz se haverá pontos flutuantes de Outliers
#notch cria um entalho na mediana

plt.boxplot(base.Volume, vert = False, showfliers = False, 
            notch = True, patch_artist = True)
plt.title("arvores")
plt.xlabel("volume")
# Out:
# Text(0.5, 0, 'volume')

# %%
#Visualizando dados por linha

plt.boxplot(base.T)
plt.title("arvores")
plt.xlabel("dados")
# Out:
# Text(0.5, 0, 'dados')

# %%
#Visualizando de 3 boxplots no mesmo gráfico

plt.boxplot(base.Volume, vert = False)
plt.boxplot(base.Girth, vert = False)
plt.boxplot(base.Height, vert = False)
plt.title("arvores")
plt.xlabel("dados")
# Out:
# Text(0.5, 0, 'dados')
